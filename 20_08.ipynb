# %% [markdown]
# <a href="https://colab.research.google.com/github/codeby-Ali/Python/blob/main/20_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First Python Program

# %%
print("My first python program")
# Out:
# My first python program

# %%
print("I am Syed Ali Taqvi")
#print("I live in Noida")
print("I am admitted to BU")
# Out:
# I am Syed Ali Taqvi
# I am admitted to BU

# %%
a= 10
b=20

print("a")
print(a)
# Out:
# a
# 10

# %%
a= 60
b= 20
#c= a+b
print (" a+b = ", a+b)
print (" a-b = ", a-b)
print (" a*b = ", a*b)
print (" a/b = ", a/b)
# Out:
#  a+b =  80
#  a-b =  40
#  a*b =  1200
#  a/b =  3.0

# %%
p= 100
r= 20
t= 30

print(" Simple Intrest =", (p*r*t)/100)
# Out:
#  Simple Intrest = 600.0

# %%
a= int (input("Enter the value of a = "))
b= int (input("Enter the value of b = "))

print (a+b)
# Out:
# Enter the value of a = 90
# Enter the value of b = 90
# 180

# %%
p = int (input ("Enter principle amt "))
r = int (input ("Enter rate "))
t = int (input ("Enter time (Years) "))

print ("Simple Intrest = ", (p*r*t)/100)
# Out:
# Enter principle amt 100
# Enter rate 12
# Enter time (Years) 1
# Simple Intrest =  12.0

# %%
#Perimeter of Triangle
a = int ( input ("enter side 1 ="))
b = int ( input ("enter side 2 ="))
c = int ( input ("enter side 3 ="))

print ("Perimeter of triangle =", a+b+c)
# Out:
# enter side 1 =10
# enter side 2 =20
# enter side 3 =30
# Perimeter of triangle =  60
