# %% [markdown]
# <a href="https://colab.research.google.com/github/codeby-Ali/Python/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1st letter should not be a number in a variable
#1st can not be special character
#TYPE function is used to print class name

# %%
P= 1000
R= 5
T= 2
print("SI is ", P*R*T/100)
# Out:
# SI is  100.0

# %%
P= int (input("Enter value of P"))
R= int (input("Enter rate R"))
T= int (input("Enter specified time"))
print ("SI", P*R*T/100)
# Out:
# Enter value of P1000
# Enter rate R5
# Enter specified time2
# SI 100.0

# %%
#Convert Celcius to Fahreneit
C= float(input("Enter tempertaure = "))
F= (C*9/5)+32
print ("Desired Temperature", F)
# Out:
# Enter tempertaure =  27
# Desired Temperature 80.6

# %%
C= 27
F= (C*9/5)+32
print ("Desired Temperature", F)
# Out:
# Desired Temperature 80.6

# %%
a=5
b=10
a,b=b,a
print (a,b)
# Out:
# 10 5

# %%
n = m = 4
m= m+1
print (m,n)
# Out:
# 5 4

# %%
x= 2
y=x
x=5
print(y)
# Out:
# 2

# %%
type(42)
# Out:
# int
